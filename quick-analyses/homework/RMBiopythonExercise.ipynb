# %% [markdown]
# # New Section

# %% [markdown]
# ## Practice using Biopython mudules
#
# http://biopython.org/DIST/docs/tutorial/Tutorial.html
#
# ### Load file
#
# 1) Use `SeqIO.read()` to load **one_nt_seq.fa**, call it **one_nt**
#
# 2) Use `SeqIO.parse()` to load **multiple_nt_seqs.fa** call it **mult_nt**
#
# ### Transcription
#
# 3) Transcribe sequences in **one_nt** and **mult_nt**.
#
# ### Translation
#
# 4) Translate sequences in **one_nt** and **mult_nt**.

# %%
from Bio import SeqIO
one_nt = Bio.SeqIO.read("one_nt_seq.fa", "fasta")
mult_nt = list(Bio.SeqIO.parse("multiple_nt_seqs.fa", "fasta"))
one_nt_RNA = (one_nt.seq).transcribe()
mult_nt_RNA = [(mult_nt[i].seq).transcribe() for i in range(len(mult_nt))]
print(one_nt_RNA)
print(mult_nt_RNA)
one_nt_protein = one_nt_RNA.translate()
mult_nt_protein = [(mult_nt_RNA[i].seq).transcribe() for i in range(len(mult_nt)
# Out:
# ...
# [Seq('GUGGCGCGAGCUUCUGAAACUAGGCGGCAGAGGCGGAGCCGCUGUGGCACUGCU...GAG'), Seq('GGAUACAGAAGUGAUGUGAGUGUCUGCGAGCGUGGUCUCGCGGGCGGGUGACGU...GAG')]
